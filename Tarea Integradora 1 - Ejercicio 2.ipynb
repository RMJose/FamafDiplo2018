# %% [markdown]
# # Tarea 1 - Ejercicio 2

# %% [markdown]
# Construir una tabla de frecuencia de probabilidades dado el evento X = ’provincia donde se desarrollo el hecho’
#
#     fdp(X)
#
#
# ¿Qué información adicional es necesaria para mostrar estos datos de manera más adecuada?
# Muestre la distribución de los eventos visualmente. ¿Qué tipo de gráfico es más adecuado para mostrar esta información?

# %%
#Traemos las librerias necesarias y el set de datos

# %matplotlib inline
import pandas
import numpy
import seaborn

seaborn.set_style('whitegrid')
seaborn.set_context('talk')

#Cargamos en una variable llamada "Dataset" los datos del csv de violencia
dataset = pandas.read_csv('https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/violencia-institucional-2018-01.csv', encoding='utf8')

# %%
fdps = dataset.provincia.dropna().value_counts(normalize=True)

ax = seaborn.barplot(data=fdps.to_frame().reset_index(),
    x='index', y='provincia', color='#2ecc71')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
seaborn.despine()

# %% [markdown]
# La informacion se puede ver en forma de barras o de torta. Sobre la informacion restante, no identifico ningun dato necesario siempre y cuando no se modifique la observacion o analisis requerido. En este caso se solicita probabilidad de ocurrencia de un evento segun la provincia, lo cual se obtiene con los calculos realizados.
